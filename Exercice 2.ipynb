# %%
# %pip install hydrogibs

# %% [markdown]
# # Exercice 1

# %%
# %run ex2-1.py
# Out:
# /home/axel/.local/lib/python3.10/site-packages/openpyxl/reader/workbook.py:84: UserWarning: File contains an invalid specification for 0. This will be removed
#   warn(msg)
# /home/axel/.local/lib/python3.10/site-packages/openpyxl/reader/workbook.py:84: UserWarning: File contains an invalid specification for 0. This will be removed
#   warn(msg)

# %% [markdown]
# # Exercice 2

# %%
# %run ex2-2.py
# Out:
# /home/axel/.local/lib/python3.10/site-packages/openpyxl/reader/workbook.py:84: UserWarning: File contains an invalid specification for 0. This will be removed
#   warn(msg)
# /home/axel/.local/lib/python3.10/site-packages/openpyxl/reader/workbook.py:84: UserWarning: File contains an invalid specification for 0. This will be removed
#   warn(msg)
# /home/axel/.local/lib/python3.10/site-packages/openpyxl/reader/workbook.py:84: UserWarning: File contains an invalid specification for 0. This will be removed
#   warn(msg)
# /home/axel/.local/lib/python3.10/site-packages/openpyxl/reader/workbook.py:84: UserWarning: File contains an invalid specification for 0. This will be removed
#   warn(msg)
# /home/axel/.local/lib/python3.10/site-packages/openpyxl/reader/workbook.py:84: UserWarning: File contains an invalid specification for 0. This will be removed
#   warn(msg)
# ...

# %% [markdown]
# # Exercice 3

# %%
# %run ex2-3.py
# Out:
# /home/axel/.local/lib/python3.10/site-packages/openpyxl/reader/workbook.py:84: UserWarning: File contains an invalid specification for 0. This will be removed
#   warn(msg)
# /home/axel/.local/lib/python3.10/site-packages/openpyxl/reader/workbook.py:84: UserWarning: File contains an invalid specification for 0. This will be removed
#   warn(msg)

# %% [markdown]
# # Exercice 4

# %%
# %run ex2-4.py

# %% [markdown]
# # Exercice 5

# %%
# %run ex2-5.py
# Out:
# /home/axel/.local/lib/python3.10/site-packages/openpyxl/reader/workbook.py:84: UserWarning: File contains an invalid specification for 0. This will be removed
#   warn(msg)
# /home/axel/.local/lib/python3.10/site-packages/openpyxl/reader/workbook.py:84: UserWarning: File contains an invalid specification for 0. This will be removed
#   warn(msg)
# /home/axel/.local/lib/python3.10/site-packages/openpyxl/reader/workbook.py:84: UserWarning: File contains an invalid specification for 0. This will be removed
#   warn(msg)
# /home/axel/Documents/EPFL/Hydraulique Fluviale/Exercice 2 - Hydraulique des cours d’eau, charriage et morphologie/ex2-5.py:108: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# ...

# %% [markdown]
# # Exercice 6
